# %% [markdown]
# PCA is a feature extraction technique. It reduce the dimension of data while keeping the important features.

# %% [markdown]
# Benefits of using PCA is:
#
# 1. Dimension reduction, memory save, faster execution of algorithm
#
# 2. visualization
