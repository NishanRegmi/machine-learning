# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
X, y = make_classification(n_samples=50, n_features=2, n_classes=2, n_informative=2, n_redundant=0, random_state=41)

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf)
# Out:
# [Text(0.5769230769230769, 0.9, 'x[1] <= 0.14\ngini = 0.5\nsamples = 50\nvalue = [25, 25]'),
#  Text(0.3076923076923077, 0.7, 'x[1] <= -0.001\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.4423076923076923, 0.8, 'True  '),
#  Text(0.15384615384615385, 0.5, 'x[0] <= 0.316\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.07692307692307693, 0.3, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.23076923076923078, 0.3, 'x[0] <= 0.523\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.15384615384615385, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3076923076923077, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.46153846153846156, 0.5, 'x[1] <= 0.052\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38461538461538464, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5384615384615384, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8461538461538461, 0.7, 'x[1] <= 0.676\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.7115384615384615, 0.8, '  False'),
#  Text(0.7692307692307693, 0.5, 'x[0] <= -0.335\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6923076923076923, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8461538461538461, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9230769230769231, 0.5, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]')]

# %%
clf.feature_importances_
# Out:
# array([0.14509317, 0.85490683])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
rf.feature_importances_
# Out:
# array([0.23298496, 0.76701504])
